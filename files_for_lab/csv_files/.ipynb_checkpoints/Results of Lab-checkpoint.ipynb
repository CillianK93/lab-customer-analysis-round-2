# %%
import pandas as pd
import numpy as np
df_1=pd.read_csv('marketing_customer_analysis.csv')
df_1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response
# 0               0  DK49336     Arizona              4809.216960       No  \
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...
# ...

# %% [markdown]
# ## Dataframe Shape

# %%
df_1.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## Standardizing Columns

# %%
df_1.columns = [col_name.lower().replace(" ", "_") for col_name in df_1.columns]
df_1.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
df_1= df_1.drop(columns=['unnamed:_0'])
df_1=df_1.rename(columns={'employmentstatus':'employment_status'})
df_2=df_1.copy
df_1
# Out:
#       customer       state  customer_lifetime_value response  coverage
# 0      DK49336     Arizona              4809.216960       No     Basic  \
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employment_status gender  income  ...
# ...

# %% [markdown]
# ## Numerical and Categorical columns

# %%
df_1.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %% [markdown]
# ## Checking and dealing with NaN values

# %%
df_1.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %% [markdown]
# ## State NaN

# %%
df_1[df_1['state'].isna()]
# Out:
#       customer state  customer_lifetime_value response  coverage
# 5      HO81102   NaN              4745.181764      NaN     Basic  \
# 11     GE63585   NaN              2420.711888      NaN     Basic
# 58     BR69566   NaN             14019.833140      NaN     Basic
# 62     UF44021   NaN              2108.493744      NaN     Basic
# 126    TE60343   NaN              4716.264294      NaN     Basic
# ...        ...   ...                      ...      ...       ...
# 10837  IJ40048   NaN              4978.950257      NaN     Basic
# 10849  SO38188   NaN              5308.617246      NaN  Extended
# 10874  PD52748   NaN             10036.536340      NaN  Extended
# 10894  EX63393   NaN              6314.492009      NaN  Extended
# 10909  IV32877   NaN              6857.519928      NaN     Basic
#
#                   education effective_to_date employment_status gender
# 5      High School or Below           2/14/11          Employed      M  \
# ...

# %%
df_1['state'] = df_1['state'].fillna('')

# %% [markdown]
# ## Response NaN

# %%
df_1[df_1['response'].isna()]
# Out:
#       customer state  customer_lifetime_value response  coverage
# 5      HO81102                    4745.181764      NaN     Basic  \
# 11     GE63585                    2420.711888      NaN     Basic
# 58     BR69566                   14019.833140      NaN     Basic
# 62     UF44021                    2108.493744      NaN     Basic
# 126    TE60343                    4716.264294      NaN     Basic
# ...        ...   ...                      ...      ...       ...
# 10837  IJ40048                    4978.950257      NaN     Basic
# 10849  SO38188                    5308.617246      NaN  Extended
# 10874  PD52748                   10036.536340      NaN  Extended
# 10894  EX63393                    6314.492009      NaN  Extended
# 10909  IV32877                    6857.519928      NaN     Basic
#
#                   education effective_to_date employment_status gender
# 5      High School or Below           2/14/11          Employed      M  \
# ...

# %%
df_1['response']=df_1['response'].fillna('No')

# %% [markdown]
# ## Months since last claim NaN

# %%
df_1[df_1['months_since_last_claim'].isna()]
# Out:
#       customer       state  customer_lifetime_value response  coverage
# 4      QA50777      Oregon              9025.067525       No   Premium  \
# 23     NQ71171  California              5107.071054       No     Basic
# 51     FT56968     Arizona              2590.096027       No     Basic
# 59     EP83939     Arizona              5575.751228       No     Basic
# 67     KR35099  Washington              7507.455372      Yes     Basic
# ...        ...         ...                      ...      ...       ...
# 10801  AP56340  Washington              5384.671725       No     Basic
# 10816  AW71157  California              5531.723723       No     Basic
# 10833  OQ99704  Washington              3981.775889       No     Basic
# 10834  FU99476  Washington              6770.306834       No  Extended
# 10905  FE99816      Nevada             15563.369440       No   Premium
#
#                   education effective_to_date employment_status gender
# ...

# %%
col_median =df_1['months_since_last_claim'].median()
df_1['months_since_last_claim']=df_1['months_since_last_claim'].fillna(col_median)

# %% [markdown]
# ## Number of open complaints NaN

# %%
df_1[df_1['number_of_open_complaints'].isna()]
# Out:
#       customer       state  customer_lifetime_value response  coverage
# 4      QA50777      Oregon              9025.067525       No   Premium  \
# 23     NQ71171  California              5107.071054       No     Basic
# 51     FT56968     Arizona              2590.096027       No     Basic
# 59     EP83939     Arizona              5575.751228       No     Basic
# 67     KR35099  Washington              7507.455372      Yes     Basic
# ...        ...         ...                      ...      ...       ...
# 10801  AP56340  Washington              5384.671725       No     Basic
# 10816  AW71157  California              5531.723723       No     Basic
# 10833  OQ99704  Washington              3981.775889       No     Basic
# 10834  FU99476  Washington              6770.306834       No  Extended
# 10905  FE99816      Nevada             15563.369440       No   Premium
#
#                   education effective_to_date employment_status gender
# ...

# %%
df_1['number_of_open_complaints'] =df_1['number_of_open_complaints'].fillna('0')

# %% [markdown]
# ## Vehicle class and size NaNs

# %%
df_1['vehicle_class'] =df_1['vehicle_class'].fillna('')
df_1['vehicle_size'] =df_1['vehicle_size'].fillna('')

# %% [markdown]
# ## Vehicle type NaN

# %%
#because the NaNs are so high I will drop the column
df_1=df_1.drop(columns=['vehicle_type'])

# %%
df_1.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employment_status                0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# ## Datetime Format

# %%
df_1['effective_to_date']=pd.to_datetime(df_1['effective_to_date'],errors='coerce')
df_1['effective_to_date']
# Out:
# /var/folders/hm/lc2tr7v957lgz2xk_p_fhct40000gn/T/ipykernel_10552/3717734047.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_1['effective_to_date']=pd.to_datetime(df_1['effective_to_date'],errors='coerce')
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
df_1['month'] =df_1['effective_to_date'].dt.month

# %%
df_1[df_1['month']<2]
# Out:
#       customer       state  customer_lifetime_value response  coverage
# 1      KX64629  California              2228.525238       No     Basic  \
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# 8      FM55990  California              5989.773931      Yes   Premium
# 9      QX31376      Oregon             17114.328150       No  Extended
# ...        ...         ...                      ...      ...       ...
# 10902  PP30874  California              3579.023825       No  Extended
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10909  IV32877                          6857.519928       No     Basic
#
#                   education effective_to_date employment_status gender
# ...

# %% [markdown]
# ## EDA lab

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
pd.set_option('display.max_columns', None) # displays all columns in dfs

import warnings
warnings.filterwarnings('ignore')
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  datetime64[ns]
#  7   employment_status              10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
df_1.describe()
# Out:
#        customer_lifetime_value              effective_to_date        income
# count             10910.000000                          10910  10910.000000  \
# mean               8018.241094  2011-01-29 22:50:02.749771008  37536.284785
# min                1898.007675            2011-01-01 00:00:00      0.000000
# 25%                4014.453113            2011-01-16 00:00:00      0.000000
# 50%                5771.147235            2011-01-30 00:00:00  33813.500000
# 75%                8992.779137            2011-02-14 00:00:00  62250.750000
# max               83325.381190            2011-02-28 00:00:00  99981.000000
# std                6885.081434                            NaN  30359.195670
#
#        monthly_premium_auto  months_since_last_claim
# count          10910.000000             10910.000000  \
# mean              93.196059                15.082401
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# ...

# %% [markdown]
# ## Showing the total number of responses

# %%
sns.countplot(x='response',data=df_1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='response',hue='sales_channel',data=df_1)
# Out:
# <Axes: xlabel='response', ylabel='count'>

# %%
sns.boxplot(x='response',y='total_claim_amount',data=df_1)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x='response',y='income',data=df_1)
# Out:
# <Axes: xlabel='response', ylabel='income'>

# %% [markdown]
# ## dividing into numeric and categorical dataframes

# %%
df_1['number_of_open_complaints']=df_1['number_of_open_complaints'].astype(float)
df_1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
numerical_data=df_1.select_dtypes('number')
categorical_data =df_1.select_dtypes('object')

# %%
numerical_data
# Out:
#        customer_lifetime_value  income  monthly_premium_auto
# 0                  4809.216960   48029                    61  \
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception
# 0                          7.0                             52  \
# 1                          3.0                             26
# ...

# %%
categorical_data
# Out:
#       customer       state response  coverage education employment_status
# 0      DK49336     Arizona       No     Basic   College          Employed  \
# 1      KX64629  California       No     Basic   College        Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor          Employed
# 3      XL78013      Oregon      Yes  Extended   College          Employed
# 4      QA50777      Oregon       No   Premium  Bachelor     Medical Leave
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        Unemployed
# 10906  KX53892      Oregon       No     Basic   College          Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor          Employed
# 10908  WA60547  California       No   Premium   College          Employed
# 10909  IV32877                   No     Basic  Bachelor        Unemployed
#
#       gender location_code marital_status     policy_type        policy
# ...

# %% [markdown]
# ## Checking the normality of the numerical values visually

# %%
for col in numerical_data.columns:
    print(col)
    sns.distplot(numerical_data[col])
    plt.show()
# Out:
# customer_lifetime_value
# income
# monthly_premium_auto
# months_since_last_claim
# months_since_policy_inception
# number_of_open_complaints
# number_of_policies
# total_claim_amount
# month

# %%
    for col in numerical_data.columns:
        print(col)
        df_1[col].hist(bins=50)
        plt.show()
# Out:
# customer_lifetime_value
# income
# monthly_premium_auto
# months_since_last_claim
# months_since_policy_inception
# number_of_open_complaints
# number_of_policies
# total_claim_amount
# month

# %% [markdown]
# ## Do the distribution for the different numerical variables look like a normal distribution

# %% [markdown]
# #### My customer lifetime value chart follows a normal distribution and is mostly bell shaped and symmetric, my total_claim_amount follows a near normal distribution.
# #### a lot of may charts do not follow a normal distribution such months since policy inception which is to be expected as the type of data would not be expected to have a similar mean. Another chart is month which seeing that theres only two months in the data it is also excepted to not follow the normal distribution chart

# %%
correlations_matrix=numerical_data.corr()
correlations_matrix
# Out:
#                                customer_lifetime_value    income
# customer_lifetime_value                       1.000000  0.028306  \
# income                                        0.028306  1.000000
# monthly_premium_auto                          0.403069 -0.009788
# months_since_last_claim                       0.015874 -0.022708
# months_since_policy_inception                 0.016960 -0.005903
# number_of_open_complaints                    -0.030616  0.008425
# number_of_policies                            0.016024 -0.009960
# total_claim_amount                            0.232626 -0.354141
# month                                        -0.009234 -0.000443
#
#                                monthly_premium_auto  months_since_last_claim
# customer_lifetime_value                    0.403069                 0.015874  \
# income                                    -0.009788                -0.022708
# monthly_premium_auto                       1.000000                 0.008489
# ...

# %%
correlations_matrix["customer_lifetime_value"].sort_values(ascending=False)
# Out:
# customer_lifetime_value          1.000000
# monthly_premium_auto             0.403069
# total_claim_amount               0.232626
# income                           0.028306
# months_since_policy_inception    0.016960
# number_of_policies               0.016024
# months_since_last_claim          0.015874
# month                           -0.009234
# number_of_open_complaints       -0.030616
# Name: customer_lifetime_value, dtype: float64

# %%
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %% [markdown]
# ## Lab customer analysis round 5

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# ## Encoding the categorical data

# %%
data1=df_1.copy()
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage
# 0      DK49336     Arizona              4809.216960       No     Basic  \
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877                          6857.519928       No     Basic
#
#       education effective_to_date employment_status gender  income
# ...

# %%
data_cat =data1.select_dtypes('object')
data_num =data1.select_dtypes(include=np.number)

# %%
#Removing some columns that i dont think add necessary data to the ML to reduce 
data_cat=data_cat.drop(['customer','education','gender','policy_type','vehicle_size'],axis=1)

# %%
data_cat=pd.get_dummies(data_cat,drop_first=True)
data_cat
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon
# 0               True             False         False         False  \
# 1              False              True         False         False
# 2              False             False         False         False
# 3              False             False         False          True
# 4              False             False         False          True
# ...              ...               ...           ...           ...
# 10905          False             False          True         False
# 10906          False             False         False          True
# 10907           True             False         False         False
# 10908          False              True         False         False
# 10909          False             False         False         False
#
#        state_Washington  response_Yes  coverage_Extended  coverage_Premium
# 0                 False         False              False             False  \
# ...

# %%
data3=pd.concat([data_num,data_cat], axis=1)

# %%
data3
data3['state_California'].value_counts()
# Out:
# state_California
# False    7358
# True     3552
# Name: count, dtype: int64

# %% [markdown]
# ## Lab 6

# %% [markdown]
# ## x-y split + train-test split

# %%
X=data3.drop(['customer_lifetime_value'], axis=1)
y=data3['customer_lifetime_value']

# %%
data3
# Out:
#        customer_lifetime_value  income  monthly_premium_auto
# 0                  4809.216960   48029                    61  \
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception
# 0                          7.0                             52  \
# 1                          3.0                             26
# ...

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.3,random_state=42)

# %%
X_train
# Out:
#       income  monthly_premium_auto  months_since_last_claim
# 7722   67763                    73                     17.0  \
# 6888   24083                    63                     22.0
# 675    53295                    70                     12.0
# 4098       0                   104                     19.0
# 4518   43246                    62                     19.0
# ...      ...                   ...                      ...
# 5734       0                   108                      7.0
# 5191   38651                    98                     12.0
# 5390       0                    69                      5.0
# 860        0                    70                     18.0
# 7270       0                   115                     21.0
#
#       months_since_policy_inception  number_of_open_complaints
# 7722                             69                        1.0  \
# 6888                              2                        1.0
# ...

# %%
scaler= StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled =scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lm = LinearRegression()
lm.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test_scaled)
rmse = mean_squared_error(y_test,predictions, squared=True)
mae = mean_absolute_error(y_test,predictions)
print('R2_score:',round(r2_score(y_test,predictions), 2))
print('RMSE:', rmse)
print('MAE', mae)
# Out:
# R2_score: 0.12
# RMSE: 39302313.81417059
# MAE 3920.5280016036404

# %% [markdown]
# ## Model Validation
# -R2: the R2 value should range from 0 to 1, my R2 score is 0.12 which is low. it indicates a bad fit for the model and might indicate not enough data is used in the model.
#
# -RMSE: the measure of the difference between the predicted and actual value. It penalizes larger errors, in my model is very high which is another indicator that my data is a bad fit for the model
#
# -MAE:a measure of the difference between the predicted and actual values a high MAE as like in my data again indicates a bad fit for the model

# %% [markdown]
# ## Lab 7

# %% [markdown]
# ## Improving the model

# %%
sns.regplot(x=y_test, y=predictions)
# Out:
# <Axes: xlabel='customer_lifetime_value'>

# %%
#Log scaling
y_train_scaled = y_train.apply(lambda x: np.log(x) if x>0 else 0)
y_test_scaled = y_test.apply(lambda x: np.log(x) if x>0 else 0)
y_train_scaled
# Out:
# 7722     7.973824
# 6888     8.897958
# 675      8.624951
# 4098     8.146449
# 4518     7.784129
#           ...
# 5734     8.245447
# 5191     8.246919
# 5390     8.968344
# 860      8.512027
# 7270    10.546793
# Name: customer_lifetime_value, Length: 7637, dtype: float64

# %%
sns.distplot(y_train_scaled, bins=10)
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Density'>

# %%
sns.distplot(y_train, bins=10)
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Density'>

# %%
lm =LinearRegression()
lm.fit(X_train_scaled,y_train_scaled)
predictions =lm.predict(X_test_scaled)
print('R2_score:',round(r2_score(y_test_scaled,predictions), 2))
# Out:
# R2_score: 0.23

# %%
sns.regplot(x=y_test_scaled, y=predictions)
# Out:
# <Axes: xlabel='customer_lifetime_value'>

# %%
result_df = X_test
result_df["target"] = y_test
result_df["scaled_target"] = y_test_scaled
result_df["error"] = y_test_scaled - predictions
result_df.sort_values("error", ascending=False)
# Out:
#       income  monthly_premium_auto  months_since_last_claim
# 7347       0                   113                      0.0  \
# 3210       0                   198                      2.0
# 5993       0                   182                      8.0
# 6213   63624                   115                     10.0
# 4622   74140                   101                     31.0
# ...      ...                   ...                      ...
# 5489   55687                   276                     33.0
# 8835   55687                   276                     33.0
# 4475   55687                   276                     33.0
# 6576   27750                   297                     28.0
# 7685   32435                   297                     24.0
#
#       months_since_policy_inception  number_of_open_complaints
# 7347                              9                        3.0  \
# 3210                             75                        0.0
# ...

# %%
df_no_outliers = data3[data3['customer_lifetime_value'] > 3000]
df_no_outliers
# Out:
#        customer_lifetime_value  income  monthly_premium_auto
# 0                  4809.216960   48029                    61  \
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# 5                  4745.181764   50549                    61
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception
# 0                          7.0                             52  \
# 2                         34.0                             31
# ...

# %%
df_no_outliers[data_num.columns] = df_no_outliers[data_num.columns].applymap(lambda x: np.log(x) if x > 0 else 0)
df_no_outliers
# Out:
#        customer_lifetime_value     income  monthly_premium_auto
# 0                     8.478290  10.779560              4.110874  \
# 2                     9.612327  10.005096              4.605170
# 3                    10.013796  10.801166              4.574711
# 4                     9.107761  10.072175              4.762174
# 5                     8.464885  10.830698              4.110874
# ...                        ...        ...                   ...
# 10905                 9.652675   0.000000              5.533389
# 10906                 8.567781  11.021020              4.174387
# 10907                10.081354  10.592551              5.303305
# 10908                 9.390324  11.069681              5.062595
# 10909                 8.833101   0.000000              4.615121
#
#        months_since_last_claim  months_since_policy_inception
# 0                     1.945910                       3.951244  \
# 2                     3.526361                       3.433987
# ...

# %%
X = df_no_outliers.drop(['customer_lifetime_value'], axis=1)
y = df_no_outliers['customer_lifetime_value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lm = LinearRegression()
lm.fit(X_train, y_train)

predictions= lm.predict(X_test)
print('R2_score:', round(r2_score(y_test, predictions), 2))
# Out:
# R2_score: 0.13

# %% [markdown]
# ## Lab final round

# %% [markdown]
# ##Business Case Conclusions
# The object of the data was to understand customer demographics and buying behavior in an auto insurance company. We used predictive analytics to analyze the most profitable customers to understand which customers to target through one of our sales channels.
#
# The dataset includes info of each customers income, state, monthly payments, months since they last claimed and how long they have been a customer. the target variable is the customers lifetime value which might be the lifetime of the contract.
#
# I think to truly understand the dataset we would need more info on the study and maybe for me to do some more studying on python which ill keep up with during sql.
